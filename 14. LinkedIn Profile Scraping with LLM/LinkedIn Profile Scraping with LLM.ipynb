# %% [markdown]
# # Announcement-on-ML
# <a href='http://www.kgptalkie.com' target="_blank"> <img src='https://github.com/laxmimerit/Important-Announcement-on-ML/raw/master/kgptalkie_strips.png'/></a>
#
# # ML Resources
# |  ML Course | Description |
# |:---|:---|
# | [**Deploy LLM App with Ollama and Langchain in Production**](https://www.udemy.com/course/ollama-and-langchain/?referralCode=7F4C0C7B8CF223BA9327) | Master Langchain v0.3, Private Chatbot, Deploy LLM App.  Ollama, LLAMA, LLAMA 3.2, FAISS, RAG, Deploy RAG, Gen AI, LLM|
# | [**Fine Tuning LLM with HuggingFace Transformers for NLP**](https://www.udemy.com/course/fine-tuning-llm-with-hugging-face-transformers/?referralCode=6DEB3BE17C2644422D8E) | Learn how to fine tune LLM with custom dataset. You will learn basics of transformers then fine tune LLM|
# | [**Data Visualization in Python Masterclass™: Beginners to Pro**](https://bit.ly/udemy95off_kgptalkie) |  Learn to build Machine Learning and Deep Learning models using Python and its libraries like Scikit-Learn, Keras, and TensorFlow. |
# | [**Python for Machine Learning: A Step-by-Step Guide**](https://bit.ly/ml-ds-project) | Learn to build Machine Learning and Deep Learning models using Python and its libraries like Scikit-Learn, Keras, and TensorFlow. |
# | [**Deep Learning for Beginners with Python**](https://bit.ly/dl-with-python) | Neural Networks, TensorFlow, ANN, CNN, RNN, LSTM, Transfer Learning and Much More. |
# | [**Python for Linear Regression in Machine Learning**](https://bit.ly/regression-python) | Learn to build Linear Regression models using Python and its libraries like Scikit-Learn. |
# | [**Introduction to Spacy 3 for Natural Language Processing**](https://bit.ly/spacy-intro) | Learn to build Natural Language Processing models using Python and its libraries like Spacy. |
# | [**Advanced Machine Learning and Deep Learning Projects**](https://bit.ly/kgptalkie_ml_projects) | Learn to build Advanced Machine Learning and Deep Learning models using Python and transformer models like BERT, GPT-2, and XLNet. |
# | [**Natural Language Processing in Python for Beginners**](https://bit.ly/intro_nlp) | Learn to build Natural Language Processing Projects using Spacy, NLTK, and Gensim, and transformer models like BERT, GPT-2, and XLNet. |
# | [**Deployment of Machine Learning Models in Production in Python**](https://bit.ly/bert_nlp) |  Learn to deploy Machine Learning and Deep Learning models using Python and its libraries like Flask, Streamlit, and NGINX. |
# | [**R 4.0 Programming for Data Science - Beginners to Pro**](https://bit.ly/r4-ml) | Learn to build Machine Learning and Deep Learning models using R and its libraries like caret, tidyverse, and keras. |

# %% [markdown]
# ## LinkedIn Profile Scraper in Python using LLM

# %% [markdown]
# YouTube Video: https://youtu.be/SQtwhuYJk3M

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.linkedin.com/login')

# %%
driver.title
# Out:
# 'LinkedIn Login, Sign in | LinkedIn'

# %%
email = driver.find_element(By.ID, 'username')
email.send_keys(os.getenv('EMAIL'))

# %%
password = driver.find_element(By.ID, 'password')
password.send_keys(os.getenv('PASSWORD'))

# %%
password.submit()

# %%
## MAKE SURE TO USE ONLY THIS URL TO AVOID BEING STUCK IN ERRORS

url = "https://www.linkedin.com/in/samuel-njiraini"

driver.get(url)

# %%
page_source = driver.page_source

# %%
soup = BeautifulSoup(page_source, 'lxml')

# %%
soup.get_text()
# Out:
# '\n\n\n\n(17) Samuel Njiraini | LinkedIn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n          0 notifications total\n        \n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  {"data":{"entityUrn":"urn:li:collectionResponse:4HlijJjSiEXmgxSNTaZbyKnZ88db1eTefgOnimBx6wM=","elements":[{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919524,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"chameleonConfigTrackingItem":{"configLixTrackingInfoListV2":[{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919524,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"lixTreatment":"VAR_t64017_PR_1","lixKey":"chameleon.OJ_GLOBAL.web-copy-definition.64012.child.64017","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfoWrapper"},{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919525,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"lixTreatment":"VAR_t64012_PR_1","lixKey":"chameleon.OJ_GLOBAL.web-copy-definition.64012.child.64017","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfoWrapper"}],"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigTrackingItem"},"data":{"namespace":"job-posting/components/budget/benefits-comparison","message":"Review and invite {:numInstantMatches} qualified and active job seekers to apply","locale":"en_US","key":"i18n_instant_matches_value_prop","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigDataI18n"},"parentLixKey":"chameleon.OJ_GLOBAL.web-copy-definition.64012.parent","lixTreatment":"VAR_t64017_PR_1","parentLixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919525,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"lixKey":"chameleon.OJ_GLOBAL.web-copy-definition.64012.child.64017","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4990836,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"chameleonConfigTrackingItem":{"configLixTrackingInfoListV2":[{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4990836,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"lixTreatment":"VAR_t71479_PR_1","lixKey":"chameleon.PLAY_global.web-copy-definition.71479","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfoWrapper"}],"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigTrackingItem"},"data":{"namespace":"play-shared/components/game-entry-point-simple-card","message":"Solve {:gameName}","locale":"en_US","key":"games-simple-card-alt-text","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigDataI18n"},"lixTreatment":"VAR_t71479_PR_1","lixKey":"chameleon.PLAY_global.web-copy-definition.71479","$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919522,"treatmentIndex":1,"$type":"com.linkedin.voyager.dash.segments.chameleon.ChameleonConfigLixTrackingInfo"},"chameleonConfigTrackingItem":{"configLixTrackingInfoListV2":[{"lixTracking":{"urn":"urn:li:member:83039505","segmentIndex":2,"experimentId":4919522,"treatmentIndex":1,"$type":"com. ...

# %%
# Updated approach: get the main element directly (LinkedIn uses dynamic class names)
profile = soup.find('main')
print("Profile element found:", profile is not None)
# Out:
# Profile element found: True

# %%
# print(profile.get_text())

# %%
sections = profile.find_all('section', {'class': 'artdeco-card'})

# %%
len(sections)
# Out:
# 14

# %%
# sections

# %%
sections_text = [section.get_text() for section in sections]

# %%
import re

# remove multiple new lines and tabs
def clean_text(text):
    text = re.sub(r'\n+', '\n', text)
    text = re.sub(r'\t+', '\t', text)
    text = re.sub(r'\t\s+', ' ', text)
    text = re.sub(r'\n\s+', '\n', text)
    return text

# %%
sections_text = [clean_text(section) for section in sections_text]

# %%
def remove_duplicates(text):
    lines = text.split('\n')
    new_lines = []
    for line in lines:
        if line[:len(line)//2] == line[len(line)//2:]:
            new_lines.append(line[:len(line)//2])
        else:
            new_lines.append(line)

    return '\n'.join(new_lines)

# %%
sections_text = [remove_duplicates(section) for section in sections_text]

# %%
print(sections_text[1])
# Out:
# Open to work
# Data Engineer, Senior Data Engineer, Data Architect, Senior Data Architect and Data Warehouse Specialist roles
# Show details
# Edit

# %%
sections_text
# Out:
# ['\nSamuel Njiraini\nAdd verification badge\nBusiness Intelligence, PowerBI dashboards, Data Analyst , Data Visualization, SQL, Python, ETL data pipelines\nInternational Rescue Committee\nLondon Metropolitan University\nKenya\nContact info\n475 connections\nOpen to\nAdd profile section\nEnhance profile\nResources\nSend profile in a message\nSave to PDF\nSaved items\nActivity\nAbout this profile\nAbout this profile\nEnhance profile\nOpen to work\nData Engineer, Senior Data Engineer, Data Architect, Senior Data Architect and Data Warehouse Specialist roles\nShow details\nEdit\nShare that you’re hiring and attract qualified candidates.\nGet started\nShowcase your services as a section on your profile so your business can be easily discovered.\nGet started\n',
#  '\nOpen to work\nData Engineer, Senior Data Engineer, Data Architect, Senior Data Architect and Data Warehouse Specialist roles\nShow details\nEdit\n',
#  '\nShare that you’re hiring and attract qualified candidates.\nGet started\n',
#  '\nShowcase your services as a section on your profile so your business can be easily discovered.\nGet started\n',
#  '\nSuggested for you\nPrivate to you\nPrivate to you\nStand out and build your credibility\nEnhance your profile with personalized AI tips and stand out for up to 2x as many opportunities.\nTry Premium for KES0\n1-month free trial. Cancel whenever. We’ll remind you 7 days before your trial ends.\nDismiss premium promotion\n',
#  "\nAnalytics\nPrivate to you\nPrivate to you\n38 profile views\nDiscover who's viewed your profile.\n115 post impressions\nCheck out who's engaging with your posts.\nPast 7 days\n6 search appearances\nSee how often you appear in search results.\nShow all analytics\n",
#  "\nAbout\nI’m a Business Intelligence and Data Analytics Engineer with over 10 years of experience transforming data into clear, actionable insights. I specialize in creating interactive Power BI dashboards and data visualizations that help teams make informed decisions. In my role, I’ve managed large-scale data migrations, developed efficient ETL data pipelines, and ensured the accuracy of complex data across global organizations.I have led the nationwide implementation of OLMIS, a data system for children's services, supporting over 200 organizations and managing data for 10,000 health workers. This helped improve services for 1.5 million vulnerable children in Kenya, by turning raw data into actionable insights. I improved data quality and simplified processes for over 1,100 organizations countrywide.With a strong background in SQL, Python, and data visualization, I’m skilled at building ETL pipelines, optimizing data workflows, and creating custom reports that drive performance improvements and cost savings. I’m passionate about turning raw data into insights that empower teams to act competently and proficiently.Skills:Data Analysis: Python, Excel, PowerBI, Power Query, DAX, SQL, Analysis Services (SSAS)Data Engineering: Microsoft SQL Server Integration Services (SSIS), DBT, Airflow, Dagster, Azure Data FactoryDevOps: Azure DevOps, Docker, Kubernetes, Terraform, Microsoft Azure, Google Cloud Platform (GCP), Amazon Web Services (AWS)I'm always looking to grow my personal and professional network. Feel free to connect via LinkedIn or contact me directly at snjiraini@gmail.comI’m a Business Intelligence and Data Analytics Engineer with over 10 years of experience transforming data into clear, actionable insights. I specialize in creating interactive Power BI dashboards and data visualizations that help teams make informed decisions. In my role, I’ve managed large-scale data migrations, developed efficient ETL data pipelines, and ensured the accuracy of complex data across global organizations.\nI have led the nationwide implementation of OLMIS, a data system for children's services, supporting over 200 organizations and managing data for 10,000 health workers. This helped improve services for 1.5 million vulnerable children in Kenya, by turning raw data into actionable insights. I improved data quality and simplified processes for over 1,100 organizations countrywide.\nWith a strong background in SQL, Python, and data visualization, I’m skilled at building ETL pipelines, optimizing data workflows, and creating custom reports that drive performance improvements and cost savings. I’m passionate about turning raw data into insights that empower teams to act competently and proficiently.\nSkills:\nData Analysis: Python, Excel, PowerBI, Power Query, DAX, SQL, Analysis Services (SSAS)\nData Engineering: Microsoft SQL Server Integration Services (SSIS), DBT, Airflow, Dagster, Azure Data Factory\nDevOps: Azure DevOps, Docker, Kubernetes, Terraform, Microsoft Azure, Google Cloud Platform (GCP), Amazon Web Services (AWS)\nI'm always looking to grow my personal and professional network. Feel free to connect via LinkedIn or contact me directly at snjiraini@gmail.com\nTop skills\nPython (Programming Language) • Microsoft Azure • SQL • Microsoft Power BI • Microsoft Power Query\n",
#  '\nActivity\n476 followers\nCreate a post\nPosts\nComments\nLoaded 2 Posts posts\nSamuel Njiraini\n• YouYou\nBusiness Intelligence, PowerBI dashboards, Data Analyst , Data Visualization, SQL, Python, ETL data pipelines\n3w • \n3 weeks ago • Visible to anyone on or off LinkedIn\nIn May, I embarked on a journey to understand how blockchain technology, often associated with cryptocurrencies, could be applied to solve challenges beyond finance.To test my learning in a real-world setting, I joined the African Blockchain Championship, a hackathon designed to push participants to build impactful solutions within a limited time. Out of this challenge, I developed KweliVote, a blockchain-based biometric identity management system aimed at ensuring transparent and credible electoral processes.KweliVote addresses the problem of electoral fraud by introducing a secure, decentralized platform for managing voter identities. It also leverages blockchain to record election results that are immutable, cryptographically secure, and publicly verifiable from anywhere in the world.What began as a modest learning project evolved into something far greater than I anticipated — KweliVote was recognized as the second-best solution across Africa.Although I regret missing the registration deadline for the UNDP Blockchain for Good bounty, the experience reinforced a powerful belief: the future of elections lies in blockchain technology.https://lnkd.in/dabnkBW4\n…more\nThe African Blockchain Championship (@AfBlockChamp) on X\nx.com\n29                    \n6 comments\nSamuel Njiraini\n• YouYou\nBusiness Intelligence, PowerBI dashboards, Data Analyst , Data Visualization, SQL, Python, ETL data pipelines\n1yr • \n1 year ago • Visible to anyone on or off LinkedIn\nI’m happy to share that I’ve obtained a new certification: Learn DevOps: Docker, Kubernetes, Terraform and Azure DevOps from Udemy!\nCelebrating a New Certification\n19                    \n5 comments\nShow all posts\n',
#  '\nExperience\nSenior ERP Data Migration Specialist\nInternational Rescue Committee · Full-time\nDec 2020 - Present · 4 yrs 11 mosDec 2020 to Present · 4 yrs 11 mos\nNairobi\nERP Master data management for Dynamics 365 for more than 70 countries globally\nMicrosoft Dynamics 365, Microsoft Power Query and +5 skills\nData Manager\nChristian Aid\nAug 2018 - Dec 2022 · 4 yrs 5 mosAug 2018 to Dec 2022 · 4 yrs 5 mos\nKenya\nMaintenance and updating of ICT4D databases and management information systems at Christian AidSupported the Monitoring Evaluation and Learning (MEAL) team to improve data accuracy, consistency, and timeliness.Leading quantitative, qualitative, and participatory data collection efforts in the field by designing survey forms using KOBO and ODKRepresent Christian Aid in National Child Protection Technical Working Groups (TWG)Maintenance and updating of ICT4D databases and management information systems at Christian Aid\nSupported the Monitoring Evaluation and Learning (MEAL) team to improve data accuracy, consistency, and timeliness.\nLeading quantitative, qualitative, and participatory data collection efforts in the field by designing survey forms using KOBO and ODK\nRepresent Christian Aid in National Child Protection Technical Working Groups (TWG)\nMonitoring and Evaluation, Microsoft Excel and +2 skills\nBusiness Intelligence Analyst\nOne Acre Fund\nJul 2017 - Feb 2018 · 8 mosJul 2017 to Feb 2018 · 8 mos\nNairobi\nImplement a Data Warehouse from SAP and other in-house databases using automated Extraction Transformation and Loading (ETL) packages developed in SSIS. Culminate all this by designing beautiful PowerBI dashboards turning the data into Business Insight.\nSQL Server Integration Services (SSIS), Agile Project Management and +4 skills\nSenior Associate Database Programmer\nMEASURE Evaluation\nFeb 2016 - Jun 2017 · 1 yr 5 mosFeb 2016 to Jun 2017 · 1 yr 5 mos\nNairobi\nOLMIS, a system I developed for Fhi360 to manage data on Orphans and Vulnerable Children (OVC) became a National System by USAID directive. I oversaw National rollout to all 47 counties in Kenya.\nMicrosoft SQL Server, Visual Basic .NET (VB.NET) and +4 skills\nDatabase Developer\nFHI 360\nOct 2011 - Jan 2016 · 4 yrs 4 mosOct 2011 to Jan 2016 · 4 yrs 4 mos\nNakuru\n•\tDesign, development and implementation of OLMIS, an OVC Longitudinal Management System using .NET 3.5 desktop and SQL Server backend.•\tPrepare documentation and assist OLMIS users.• Design both standard and ad-hoc reports from OVC database.•\tDesign, development and implementation of OLMIS, an OVC Longitudinal Management System using .NET 3.5 desktop and SQL Server backend.\n•\tPrepare documentation and assist OLMIS users.\n• Design both standard and ad-hoc reports from OVC database. \nMicrosoft SQL Server, Visual Basic .NET (VB.NET) and +3 skills\nShow all 6 experiences\n',
#  '\nEducation\nLondon Metropolitan University\nBachelors, Bsc. Computing and Information Systems\n2006 - 2006\n',
#  '\nLicenses & certifications\nLearn DevOps: Docker, Kubernetes, Terraform and Azure DevOps\nUdemy\nIssued Mar 2024\nAzure DevOps, Docker and +5 skills\nLearnDevOps\n',
#  '\nSkills\nDocker\nLearn DevOps: Docker, Kubernetes, Terraform and Azure DevOps\nKubernetes\nLearn DevOps: Docker, Kubernetes, Terraform and Azure DevOps\nShow all 31 skills\n',
#  "\nRecommendations\nReceived\nGiven\nCarolyne Karega, PMP®, M.S\n· 1stFirst degree connection\nTechnical Project Manager | Driving Impact Through Data-Driven Project Leadership & AI-Enabled Innovation\nApril 21, 2025, Samuel was senior to Carolyne but didn't manage Carolyne directly\nI had the pleasure of working with Samuel on a large-scale ERP data migration project, which he led with exceptional professionalism and clarity. His deep expertise in data migration, combined with strong analytical and problem-solving skills, played a critical role in the success of our implementation.Samuel’s ability to manage complex datasets, streamline ETL processes, and maintain high standards of data quality truly set him apart. He was always approachable, willing to share knowledge, and ready to step in to resolve challenges as they arose.What stood out most was his positive attitude and collaborative leadership style. Samuel fostered a supportive team environment where everyone felt heard and empowered to contribute. His clear communication and focus on results made it easy for the team to stay aligned and deliver on key milestones.It was a pleasure working with Samuel, and I highly recommend him for any role requiring a skilled, dedicated, and team-oriented data professional.I had the pleasure of working with Samuel on a large-scale ERP data migration project, which he led with exceptional professionalism and clarity. His deep expertise in data migration, combined with strong analytical and problem-solving skills, played a critical role in the success of our implementation.\nSamuel’s ability to manage complex datasets, streamline ETL processes, and maintain high standards of data quality truly set him apart. He was always approachable, willing to share knowledge, and ready to step in to resolve challenges as they arose.\nWhat stood out most was his positive attitude and collaborative leadership style. Samuel fostered a supportive team environment where everyone felt heard and empowered to contribute. His clear communication and focus on results made it easy for the team to stay aligned and deliver on key milestones.\nIt was a pleasure working with Samuel, and I highly recommend him for any role requiring a skilled, dedicated, and team-oriented data professional.\nCarolyne Karega, PMP®, M.S\n· 1stFirst degree connection\nTechnical Project Manager | Driving Impact Through Data-Driven Project Leadership & AI-Enabled Innovation\nApril 19, 2025, Samuel managed Carolyne directly\nIf you ever get the chance to work with Carolyne, take it. She's one of those rare project managers who not only brings structure and clarity to every project, but also manages to do it with heart and intention. Over the years, she’s led complex, global initiatives across Finance, HR, IT, and Supply Chain — and always finds a way to make collaboration feel effortless, even when juggling cross-functional teams in 50+ countries.What stands out most is her ability to translate complexity into action. Whether it’s an ERP implementation, a digital transformation effort, or a system migration, Carol doesn’t just check the boxes — she creates real, lasting impact. Her technical toolkit is impressive (Dynamics 365, Power BI, Jira, SQL — the list goes on), but it’s her people skills and problem-solving mindset that really set her apart.She’s constantly leveling up — studying for her CAPM, digging into Agile, Azure, server infrastructure — and it shows. If you’re looking for someone who brings both precision and perspective to every challenge, Carol’s the one you want on your team.If you ever get the chance to work with Carolyne, take it. She's one of those rare project managers who not only brings structure and clarity to every project, but also manages to do it with heart and intention. Over the years, she’s led complex, global initiatives across Finance, HR, IT, and Supply Chain — and always finds a way to make collaboration feel effortless, even when juggling cross-functio ...
#  '\nInterests\nTop Voices\nCompanies\nGroups\nSchools\nBill Gates\n· 3rdThird degree connection\nChair, Gates Foundation and Founder, Breakthrough Energy\n38,999,565 followers\nFollowing\nDavid Miliband\n· 3rdThird degree connection\nPresident & CEO at International Rescue Committee\n91,571 followers\nFollowing\nAbsa Group\nAbsa Group\n942,163 followers\nFollowing\nUSAID\nUSAID\n2,407,440 followers\nFollowing\nShow all companies\nMobile Monday Kenya\n281 members\nJoined\nJoined Mobile Monday Kenya group\nLondon Metropolitan University\n190,394 followers\nFollowing\n']

# %% [markdown]
# ### Profile Data Parsing using LLM

# %%
from langchain_ollama import ChatOllama

from langchain_core.prompts import (SystemMessagePromptTemplate, 
                                    HumanMessagePromptTemplate,
                                    ChatPromptTemplate)



from langchain_core.output_parsers import StrOutputParser

base_url = "http://localhost:11434"
# model = 'llama3.2:3b'
model = "qwen2.5:7b"

llm = ChatOllama(base_url=base_url, model=model)


system = SystemMessagePromptTemplate.from_template("""You are helpful AI assistant who answer LinkedIn profile parsing related 
                                                    user question based on the provided profile text data.""")

def ask_llm(prompt):
    prompt = HumanMessagePromptTemplate.from_template(prompt)

    messages = [system, prompt]
    template = ChatPromptTemplate(messages)

    qna_chain = template | llm | StrOutputParser()

    return qna_chain.invoke({})

# %%
llm
# Out:
# ChatOllama(model='qwen2.5:7b', base_url='http://localhost:11434')

# %%
ask_llm("hello")
# Out:
# 'Hello! How can I assist you with parsing a LinkedIn profile? Do you have a specific profile text or any particular questions about profile analysis?'

# %%
template = """
Extract and return the requested information from the LinkedIn profile data in a concise, point-by-point format (up to 5 points). Avoid preambles or any additional context.

### LinkedIn Profile Data:
{}

### Information to Extract:
Extract '{}' in bullet points, limiting the output to 5 points. Provide only the necessary details.
Remember, It is LinkedIn profile data.

### Extracted Data:"""

context = sections_text[0]
k = "Name and Headline"

prompt = template.format(context, k)
response = ask_llm(prompt)

# %%
print(response)
# Out:
# - Name: Samuel Njiraini
# - Headline: Business Intelligence, PowerBI dashboards, Data Analyst, Data Visualization, SQL, Python, ETL data pipelines

# %%
section_keys = ['Name and Headline']
for section in sections_text[1:]:
    # print(section.strip().split('\n'))
    section_keys.append(section.strip().split('\n')[0])

section_keys
# Out:
# ['Name and Headline',
#  'Open to work',
#  'Share that you’re hiring and attract qualified candidates.',
#  'Showcase your services as a section on your profile so your business can be easily discovered.',
#  'Suggested for you',
#  'Analytics',
#  'About',
#  'Activity',
#  'Experience',
#  'Education',
#  'Licenses & certifications',
#  'Skills',
#  'Recommendations',
#  'Interests']

# %%
# sections_text
responses = {}

for k,context in zip(section_keys, sections_text):
    prompt = template.format(context, k)
    response = ask_llm(prompt=prompt)
    responses[k] = response

# %%
print(responses)
# Out:
# {'Name and Headline': '- Name: Samuel Njiraini\n- Headline: Business Intelligence, PowerBI dashboards, Data Analyst, Data Visualization, SQL, Python, ETL data pipelines', 'Open to work': '- Open to work', 'Share that you’re hiring and attract qualified candidates.': '- Share that you’re hiring and attract qualified candidates.', 'Showcase your services as a section on your profile so your business can be easily discovered.': '- Showcase your services as a section on your profile\n- So your business can be easily discovered', 'Suggested for you': '- Suggested for you\n- Private to you\n- Private to you\n- Stand out and build your credibility\n- Enhance your profile with personalized AI tips and stand out for up to 2x as many opportunities.', 'Analytics': '- Private to you\n- 38 profile views\n- 115 post impressions\n- 6 search appearances (past 7 days)', 'About': '- Over 10 years of experience transforming data into actionable insights.\n- Specializes in creating interactive Power BI dashboards and data visualizations for informed decision-making.\n- Managed large-scale data migrations and developed efficient ETL data pipelines.\n- Led the nationwide implementation of OLMIS, supporting over 200 organizations and improving services for 1.5 million vulnerable children in Kenya.\n- Ensured data accuracy across global organizations and simplified processes for over 1,100 organizations countrywide.', 'Activity': '- 476 followers\n- Created a post on May discussing blockchain application and KweliVote project\n- Recognized as second-best solution in African Blockchain Championship for KweliVote\n- Shared new certification obtained from Udemy in DevOps technologies\n- Post received 6 comments on the KweliVote project', 'Experience': '- Senior ERP Data Migration Specialist at International Rescue Committee (Dec 2020 - Present)\n- Data Manager at Christian Aid (Aug 2018 - Dec 2022)\n- Business Intelligence Analyst at One Acre Fund (Jul 2017 - Feb 2018)\n- Senior Associate Database Programmer at MEASURE Evaluation (Feb 2016 - Jun 2017)\n- Database Developer at FHI 360 (Oct 2011 - Jan 2016)', 'Education': '- London Metropolitan University, Bsc. Computing and Information Systems (2006 - 2006)', 'Licenses & certifications': '- Learn DevOps: Docker, Kubernetes, Terraform and Azure DevOps (Udemy, Issued Mar 2024)\n- Azure DevOps\n- Docker', 'Skills': '- Docker\n- Kubernetes\n- Terraform\n- Azure DevOps\n- Learn DevOps', 'Recommendations': '- Received: 1 recommendation from Carolyne Karega, PMP®, M.S\n- Given: No information provided\n- Recommendations (from Carolyne):\n  - Exceptional professionalism and clarity in project management\n  - Strong analytical and problem-solving skills\n  - Positive attitude and collaborative leadership style\n  - Approachable and supportive team environment\n  - Clear communication and focus on results', 'Interests': '- Bill Gates\n- David Miliband\n- Absa Group\n- USAID\n- Mobile Monday Kenya'}

# %%
import json

with open('linkedin_profile_data.json', 'w') as f:
    json.dump(responses, f, indent=4)

# %% [markdown]
# ### Second Level of LLM Call

# %%
template = """You are provided with LinkedIn profile data in JSON format.
            Parse the data according to the specified schema, correct any spelling errors,
            and condense the information if possible.

### LinkedIn Profile JSON Data:
{context}

### Schema You need to follow:
You need to extract
Name:
Headline:
About:
Experience:
Education:
Skills:
Projects:
Summary:

Do not return preambles or any other information.
### Parsed Data:"""

prompt = template.format(context=responses).replace("{", "{{").replace("}", "}}")
response = ask_llm(prompt=prompt)
# response

# %%
print(response)
# Out:
# Name: Samuel Njiraini
#
# Headline: Business Intelligence, PowerBI dashboards, Data Analyst, Data Visualization, SQL, Python, ETL data pipelines
#
# About: Over 10 years of experience transforming data into actionable insights. Specializes in creating interactive Power BI dashboards and data visualizations for informed decision-making. Managed large-scale data migrations and developed efficient ETL data pipelines. Led the nationwide implementation of OLMIS, supporting over 200 organizations and improving services for 1.5 million vulnerable children in Kenya. Ensured data accuracy across global organizations and simplified processes for over 1,100 organizations countrywide.
#
# Experience:
# - Senior ERP Data Migration Specialist at International Rescue Committee (Dec 2020 - Present)
# - Data Manager at Christian Aid (Aug 2018 - Dec 2022)
# - Business Intelligence Analyst at One Acre Fund (Jul 2017 - Feb 2018)
# - Senior Associate Database Programmer at MEASURE Evaluation (Feb 2016 - Jun 2017)
# - Database Developer at FHI 360 (Oct 2011 - Jan 2016)
#
# Education:
# - London Metropolitan University, Bsc. Computing and Information Systems (2006 - 2006)
#
# Skills:
# - Docker
# - Kubernetes
# - Terraform
# - Azure DevOps
# - Learn DevOps
#
# Projects:
# - Created a post on May discussing blockchain application and KweliVote project
# - Recognized as second-best solution in African Blockchain Championship for KweliVote
# - Shared new certification obtained from Udemy in DevOps technologies
#
# Summary:
# Open to work. Share that you’re hiring and attract qualified candidates. Showcase your services on your profile for easy discovery. Analytics show 38 profile views, 115 post impressions, and 6 search appearances (past 7 days). Received 1 recommendation from Carolyne Karega, PMP®, M.S, highlighting exceptional professionalism, strong analytical skills, positive attitude, clear communication, and focus on results.
